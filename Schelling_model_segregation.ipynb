# %% [markdown]
# <a href="https://colab.research.google.com/github/mwtam/blog/blob/main/Schelling_model_segregation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Helper with no parameters

# %%
from random import shuffle, randrange
from itertools import product


def print_map(m):
    n_i = len(m)
    n_j = len(m[0])
    print('-' * (n_j+2))
    for l in m:
        print('|' + ''.join(l) + '|')


def neighbors(m, i, j):
    n_i = len(m)
    n_j = len(m[0])

    counter = {}
    counter['o'] = 0
    counter['x'] = 0
    counter[' '] = 0

    for ii, jj in [(i+1, j), (i-1, j), (i, j+1), (i, j-1), (i+1, j+1), (i-1, j+1), (i+1, j-1), (i-1, j-1), ]:
        if ii < 0 or ii > n_i-1 or jj < 0 or jj > n_j-1:
            continue
        counter[m[ii][jj]] += 1

    return counter['o'], counter['x'], counter[' ']

# %%
def build_map():
    n_i = 20
    n_j = 40

    m = [[' '] * n_j for _ in range(n_i)]

    rand_position = [(i, j) for i in range(n_i) for j in range(n_j)]
    shuffle(rand_position)

    n = n_i * n_j
    percent = int(n*48/100)

    for p in range(percent):
        m[rand_position[p][0]][rand_position[p][1]] = 'o'
    for p in range(percent, percent*2):
        m[rand_position[p][0]][rand_position[p][1]] = 'x'

    return m

# %%
def move(m, i, j, n_o_max=99, n_x_max=99):
    # Setting the n_o_max to 99 means don't care.
    n_i = len(m)
    n_j = len(m[0])
    for _ in range(90):
        ii = randrange(0, n_i)
        jj = randrange(0, n_j)
        n_o, n_x, _ = neighbors(m, ii, jj)
        if m[ii][jj] == ' ' and n_o <= n_o_max and n_x <= n_x_max:
            m[i][j], m[ii][jj] = m[ii][jj], m[i][j]
            break

# %%
def tick(m, threshold):
    n_i = len(m)
    n_j = len(m[0])

    move_intented = 0

    for i, j in product(range(n_i), range(n_j)):
        n_o, n_x, _ = neighbors(m, i, j)
        # print(f"{i=}, {j=}, {n_o=}, {n_x=}, {n_space=}")

        # The number of neighbors is 8 at max.
        if m[i][j] == 'o' and n_x > threshold:
            # n_x+1 means
            ## OK to move to somewhere a little worse
            ## It helps explore better overall pattern
            ## by don't stuck in a local minimal.
            move(m, i, j, n_x_max=n_x+1)

            # n_x means
            ## move somewhere at least as good
            # move(m, i, j, n_x_max=n_x)

            move_intented += 1
        if m[i][j] == 'x' and n_o > threshold:
            move(m, i, j, n_o_max=n_o+1)
            # move(m, i, j, n_o_max=n_o)

            move_intented += 1
    return move_intented

# %%
def main():
    m = build_map()
    print_map(m)
    for threshold in range(4, -1, -1):
        for n_iter in range(1000):
            if tick(m, threshold) < 4*threshold:
                # Break early and tighten the threshold
                # in the next iteration if no much move.
                print(f"n_iter={n_iter}")
                break
        print()
        print()
        print(threshold)
        print_map(m)
        threshold -= 1

# %%
main()
# Out:
# ------------------------------------------
# |xoooxoxox  o oxooooxxxoxxoo oxxxxxxooox |
# |oxoxooxoxxxxoox oxoxxxoxxoooooxxoxoooxox|
# |ooxxooxoxooxxxooooooxxoxxoxxoxoooooxxxxx|
# |xxoxxoxxxxo oxoxxoxxooooxoxxxxo oxxxooxo|
# |x xoxxxox xooxooxoooxxxxxxoxooxoooxoxo x|
# |oxoxxooxxxooxxxooxooxoooxxoxooxxxooooxxo|
# |oooxooxxxxooxoxooxoxooxxxxoooxoxxooxoxoo|
# |xoxxoxxoxooxxoxxxooxoxox xoxxxooxxxoxxx |
# |oooxoxxxxooxoxxoxooooooxooxxoxx oxxoxxoo|
# |oxooxooooxooxooooooxooxoooooooxxxxxxxxoo|
# |ox o oxoxooxxxxxxxxoooxoxxx oxoooooxxxox|
# | ooxooooxo oxoooxxxoxxxxoxooxxooxxoxoxxo|
# |xoxx oxoxoxxxoooxoxoxoxooooxox oxxooxoxx|
# |xxoxxox oxoo oxoxxo xxx oooxoxxooxxxoxxx|
# |oxxoxxoxxxoxxxxxxxxoxoxxxoxoooxoxxoxooxx|
# |ooooxxxooooooxoxooxoxoooxoxxooooxxoxo xx|
# |oxxxxxxxooxo xxxoxxxxoxooooooooxxoxoooxo|
# |ooxoooxooooxooxoooxxoxoxoxxoxxxxoxxxoo x|
# |o ooooooxxoxx oxoxo oxxoxooxoxxxoxxooxoo|
# |oxoxooxxxxooxxxxxxoxxooxoooxxooooxx xoox|
# n_iter=5
#
#
# 4
# ------------------------------------------
# |xooooox xooooooooooxxxxxxooooxxxxxxoooxo|
# |ooooooxxxxoooooooooxxxxxx ooooxxxxoooxxx|
# |ooxx xxxxxoooooooooxxx xxxxxoxoooooxxxxx|
# |xxxxxxxxxxoooooooo  oxxxxxxxxxoooo xxxxx|
# |xxx xxxxxxoooooooooooxxxxxxxxoooooooxxxx|
# |oooxxxxxxxoooooooooooo xxxxx xxxoooooxxo|
# |ooo xxxxxxoooooooooooooxxxxxxxxxxooo xxo|
# |oooooxxxxooooo ooooooooooxxxxxx xxxxxxxo|
# |ooooooxxoooooxxxooooooooooxxxxxxxxxxxxoo|
# |ooooooooooooxxxx oooooooooo ooxxxxxxxx o|
# |oooooooooooxxxxxxxoooooooooooooxxxxxxxxx|
# |oooooooooooxxx xxxxxxxx oooooooxxxxxxxx |
# |x xxoooooooxxxxxxxxxxxxxoooooo xxxxxxxxx|
# |xxxxxooooooxxxxxxxxxxxxxoooooooxxxxxxxxx|
# |oxxxxxoooooxxxxxxxxxxxxoooooooooxxxxxxxx|
# |ooxxxxxoooooxxxxxxxxxxxoooooooooxxxxxxxx|
# |oooxxxooooooxxxx xxxxxxooooooooxxxxx oxo|
# |ooooooooooo xxxx  xx xooooooo xxxxxxooox|
# |ooooooooooooxxxxxxxxxxoooooooxxxxxx oooo|
# |ooooooxxxxooxxxxxx xxoo oooxxooooxxxxoox|
# n_iter=11
#
#
# 3
# ------------------------------------------
# |xoooo xxxooooooooooxxxxxx oooxxxxxooooxo|
# |oooxxxxxxoooooooooo xxxxxxx xxxxxoooo xx|
# |o xxxxxxxoooooooooooxxxxxxxxxxxx ooooxxx|
# |xxxxxxxxxooooooooooo xxxxxxxxxxxxooooxxx|
# |xxxxxxxx ooooooooooooxxxxxxxxxxxxooo xxx|
# |ooxxxxxxooooooooooooooxxxxxxxxxxx o xxxx|
# |ooo xxxxoooooooooooooooxxxxxxxxxxxxxxxxx|
# |ooooo oooooooooooooooooo xxxxxxxxxxxxxxx|
# |oooooooooooooooooooooooooo xxxxxxxxxxxxx|
# |ooooooooooooo xx oooooooooooxxxxxxxxxxxx|
# |oooooooooooo xxxxxxxoooooooo xxxxxxxxxxx|
# |ooooooooooooxxxxxxxxxooooooooxxxxxxxxxxx|
# |x ooooooooooxxxxxxxxxxooooooooxxxxxxxxxx|
# |xxxx oooooooxxxxxxxxxxxooooooo xxxxxxxxx|
# |o xxxoooooooxxxxxxxxxxx oooooooxxxxxxxxx|
# |ooo  oooooooxxxxxxxxxxxooooooooxxxxxxxxx|
# |ooooooooooooxxxxxxxxxx ooooooooxxxxxxxxx|
# |ooooooooooooxxxxxxxxxxooooooooo xxxxxxxx|
# |ooooooooooooxxxxxxxxx ooooooooooxxxxxxxx|
# |oooooooo oooxxxxxxxxxooooooooooooxxxxx x|
# n_iter=73
#
#
# 2
# ------------------------------------------
# |xxooooooooooooooooooxxxxxxxxxxxxxxxxxxxx|
# |xxxoooooooooooooooo xxxxxxxxxxxxxxxxxxxx|
# |x ooooooooooooooooooxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooo xxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooooxxxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo xxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo xxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooooo xxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooooooxxxxxxxxxxxxxxxxx|
# |ooooooooooooooo  oooooo xxxxxxxxxxxxxxxx|
# |ooooooooooooo xxxx oooooxxxxxxxxxxxxxxxx|
# |oooooooooooo xxxxxx ooooxxxxxxxxxxxxxxxx|
# |ooooooooooo xxxxxxxx oooo xxxxxxxxxxxxxx|
# |ooooooooooo xxxxxxxxxooooo xxxxxxxxxxxxx|
# |ooooooooooo xxxxxxxx oooooo xxxxxxxxxxxx|
# |ooooooooooo xxxxxxxx ooooooo xxxxxxxxxxx|
# |oooooooooooxxxxxxxxx oooooooo xxxxxxxxxx|
# |ooooooooooo xxxxxxxx ooooooooo xxxxxxxxx|
# |ooooooooooo xxxxxxxx oooooooooo xxxxxxxx|
# |ooooooooooooxxxxxxxxxoooooooooooxxxxxxxx|
# n_iter=78
#
#
# 1
# ------------------------------------------
# |oooooooooooooooo xxxxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooo xxxxxxxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooo xxxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooo xxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooo xxxxxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooo xxxxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooo xxxxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooo xxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooo xxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooo  xxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo xxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo xxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo xxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo xxxxxxxxxxxxxxxxxx|
# |ooooooooo ooooooooooo xxxxxxxxxxxxxxxxxx|
# |oooooooo oooooooooooo xxxxxxxxxxxxxxxxxx|
# |ooooooo  ooooooooooooo xxxxxxxxxxxxxxxxx|
# |ooooooo   oooooooooooo xxxxxxxxxxxxxxxxx|
# |oooooooo x ooooooooooo  xxxxxxxxxxxxxxxx|
# |oooooooo x ooooooooooooxxxxxxxxxxxxxxxxx|
#
#
# 0
# ------------------------------------------
# |ooooooooooooooooooooo  xxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooooo xxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooooo xxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooooo  xxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooooo xxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo   xxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo xxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooooo  xxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooo  xxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooo xxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooooo xxxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooooo  xxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooooo  xxxxxxxxxxxxxxxxxxxx|
# |ooooooooooooooooo o xxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooo    xxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooo xxxxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooo xxxxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooo xxxxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooo xxxxxxxxxxxxxxxxxxxxxxx|
# |oooooooooooooooo xxxxxxxxxxxxxxxxxxxxxxx|
